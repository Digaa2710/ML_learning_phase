# %% [markdown]
# <a href="https://colab.research.google.com/github/Digaa2710/ML_learning_phase/blob/main/Synapse2Task.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df=pd.read_csv('train.csv')
df.head()
# Out:
#    id Sex  Length  Diameter  Height     Weight  Shucked Weight  \
# 0   0   I  1.5250    1.1750  0.3750  28.973189       12.728926
# 1   1   I  1.1000    0.8250  0.2750  10.418441        4.521745
# 2   2   M  1.3875    1.1125  0.3750  24.777463       11.339800
# 3   3   F  1.7000    1.4125  0.5000  50.660556       20.354941
# 4   4   I  1.2500    1.0125  0.3375  23.289114       11.977664
#
#    Viscera Weight  Shell Weight  Age
# 0        6.647958      8.348928    9
# 1        2.324659      3.401940    8
# 2        5.556502      6.662133    9
# 3       10.991839     14.996885   11
# 4        4.507570      5.953395    8

# %%
df.size
# Out:
# 740510

# %%
df.drop('id',axis=1,inplace=True)
df.head()
# Out:
#   Sex  Length  Diameter  Height     Weight  Shucked Weight  Viscera Weight  \
# 0   I  1.5250    1.1750  0.3750  28.973189       12.728926        6.647958
# 1   I  1.1000    0.8250  0.2750  10.418441        4.521745        2.324659
# 2   M  1.3875    1.1125  0.3750  24.777463       11.339800        5.556502
# 3   F  1.7000    1.4125  0.5000  50.660556       20.354941       10.991839
# 4   I  1.2500    1.0125  0.3375  23.289114       11.977664        4.507570
#
#    Shell Weight  Age
# 0      8.348928    9
# 1      3.401940    8
# 2      6.662133    9
# 3     14.996885   11
# 4      5.953395    8

# %%
height_df=df[df['Height']==0]
height_df.head()
# Out:
#       Sex    Length  Diameter  Height    Weight  Shucked Weight  \
# 762     I  0.787500    0.5750     0.0  3.727959        1.417475
# 3585    I  0.737087    0.5250     0.0  2.267960        0.737087
# 8749    I  0.525000    0.3750     0.0  2.863300        1.204854
# 9320    I  0.462500    0.3250     0.0  0.893009        0.354369
# 11542   I  0.637500    0.4375     0.0  1.771844        0.637864
#
#        Viscera Weight  Shell Weight  Age
# 762          0.807961      1.133980    4
# 3585         0.652038      0.708738    5
# 8749         0.425243      0.425243    4
# 9320         0.141747      0.269320    7
# 11542        0.396893      0.462525    3

# %%
df=df[df['Height']!=0]
df.head()
# Out:
#   Sex  Length  Diameter  Height     Weight  Shucked Weight  Viscera Weight  \
# 0   I  1.5250    1.1750  0.3750  28.973189       12.728926        6.647958
# 1   I  1.1000    0.8250  0.2750  10.418441        4.521745        2.324659
# 2   M  1.3875    1.1125  0.3750  24.777463       11.339800        5.556502
# 3   F  1.7000    1.4125  0.5000  50.660556       20.354941       10.991839
# 4   I  1.2500    1.0125  0.3375  23.289114       11.977664        4.507570
#
#    Shell Weight  Age
# 0      8.348928    9
# 1      3.401940    8
# 2      6.662133    9
# 3     14.996885   11
# 4      5.953395    8

# %%
df['Lost Weight']=df['Weight']-(df['Shucked Weight']+df['Viscera Weight']+df['Shell Weight'])
df.head()
# Out:
# <ipython-input-125-99ca116a7991>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Lost Weight']=df['Weight']-(df['Shucked Weight']+df['Viscera Weight']+df['Shell Weight'])
#   Sex  Length  Diameter  Height     Weight  Shucked Weight  Viscera Weight  \
# 0   I  1.5250    1.1750  0.3750  28.973189       12.728926        6.647958
# 1   I  1.1000    0.8250  0.2750  10.418441        4.521745        2.324659
# 2   M  1.3875    1.1125  0.3750  24.777463       11.339800        5.556502
# 3   F  1.7000    1.4125  0.5000  50.660556       20.354941       10.991839
# 4   I  1.2500    1.0125  0.3375  23.289114       11.977664        4.507570
#
#    Shell Weight  Age  Lost Weight
# 0      8.348928    9     1.247378
# ...

# %%
negative_df=df[df['Lost Weight']<0]
negative_df.head()
# Out:
#    Sex  Length  Diameter  Height     Weight  Shucked Weight  Viscera Weight  \
# 10   I  0.9250    0.7250  0.2125   6.109317        2.693202        1.729319
# 14   M  1.3125    0.9875  0.3125  17.449117        8.547374        3.983105
# 18   I  1.1375    0.9125  0.2875  13.366789        6.860579        2.664853
# 19   I  0.6750    0.4875  0.1000   2.083688        0.878834        0.637864
# 49   I  1.1750    0.9250  0.3125  15.223681        7.923685        3.501163
#
#     Shell Weight  Age  Lost Weight
# 10      2.126212    7    -0.439417
# 14      5.244657    9    -0.326019
# 18      3.968930    7    -0.127573
# 19      0.737087    5    -0.170097
# 49      4.961163    8    -1.162330

# %%
df2=df
df2.head()
# Out:
#   Sex  Length  Diameter  Height     Weight  Shucked Weight  Viscera Weight  \
# 0   I  1.5250    1.1750  0.3750  28.973189       12.728926        6.647958
# 1   I  1.1000    0.8250  0.2750  10.418441        4.521745        2.324659
# 2   M  1.3875    1.1125  0.3750  24.777463       11.339800        5.556502
# 3   F  1.7000    1.4125  0.5000  50.660556       20.354941       10.991839
# 4   I  1.2500    1.0125  0.3375  23.289114       11.977664        4.507570
#
#    Shell Weight  Age  Lost Weight
# 0      8.348928    9     1.247378
# 1      3.401940    8     0.170097
# 2      6.662133    9     1.219029
# 3     14.996885   11     4.316891
# 4      5.953395    8     0.850485

# %%
df['LostWeight'] = df.apply(lambda row: 0 if row['Weight'] - (row['Shucked Weight'] + row['Viscera Weight'] + row['Shell Weight']) < 0 else 1, axis=1)


df.head()
# Out:
#   Sex  Length  Diameter  Height     Weight  Shucked Weight  Viscera Weight  \
# 0   I  1.5250    1.1750  0.3750  28.973189       12.728926        6.647958
# 1   I  1.1000    0.8250  0.2750  10.418441        4.521745        2.324659
# 2   M  1.3875    1.1125  0.3750  24.777463       11.339800        5.556502
# 3   F  1.7000    1.4125  0.5000  50.660556       20.354941       10.991839
# 4   I  1.2500    1.0125  0.3375  23.289114       11.977664        4.507570
#
#    Shell Weight  Age  Lost Weight  LostWeight
# 0      8.348928    9     1.247378           1
# 1      3.401940    8     0.170097           1
# 2      6.662133    9     1.219029           1
# 3     14.996885   11     4.316891           1
# 4      5.953395    8     0.850485           1

# %%
df.head()
# Out:
#   Sex  Length  Diameter  Height     Weight  Shucked Weight  Viscera Weight  \
# 0   I  1.5250    1.1750  0.3750  28.973189       12.728926        6.647958
# 1   I  1.1000    0.8250  0.2750  10.418441        4.521745        2.324659
# 2   M  1.3875    1.1125  0.3750  24.777463       11.339800        5.556502
# 3   F  1.7000    1.4125  0.5000  50.660556       20.354941       10.991839
# 4   I  1.2500    1.0125  0.3375  23.289114       11.977664        4.507570
#
#    Shell Weight  Age  Lost Weight  LostWeight
# 0      8.348928    9     1.247378           1
# 1      3.401940    8     0.170097           1
# 2      6.662133    9     1.219029           1
# 3     14.996885   11     4.316891           1
# 4      5.953395    8     0.850485           1

# %%
# Perform one-hot encoding on the 'Sex' column
df = pd.get_dummies(df, columns=['Sex'])
df.head()
# Out:
#    Length  Diameter  Height     Weight  Shucked Weight  Viscera Weight  \
# 0  1.5250    1.1750  0.3750  28.973189       12.728926        6.647958
# 1  1.1000    0.8250  0.2750  10.418441        4.521745        2.324659
# 2  1.3875    1.1125  0.3750  24.777463       11.339800        5.556502
# 3  1.7000    1.4125  0.5000  50.660556       20.354941       10.991839
# 4  1.2500    1.0125  0.3375  23.289114       11.977664        4.507570
#
#    Shell Weight  Age  Lost Weight  LostWeight  Sex_F  Sex_I  Sex_M
# 0      8.348928    9     1.247378           1      0      1      0
# 1      3.401940    8     0.170097           1      0      1      0
# 2      6.662133    9     1.219029           1      0      0      1
# 3     14.996885   11     4.316891           1      1      0      0
# 4      5.953395    8     0.850485           1      0      1      0

# %%
# Your code starts here
def crab_processing(df):
  #logic for feature engineering
  return df

df = crab_processing(df)
df.head()
# Your code ends here
# Out:
#    Length  Diameter  Height     Weight  Shucked Weight  Viscera Weight  \
# 0  1.5250    1.1750  0.3750  28.973189       12.728926        6.647958
# 1  1.1000    0.8250  0.2750  10.418441        4.521745        2.324659
# 2  1.3875    1.1125  0.3750  24.777463       11.339800        5.556502
# 3  1.7000    1.4125  0.5000  50.660556       20.354941       10.991839
# 4  1.2500    1.0125  0.3375  23.289114       11.977664        4.507570
#
#    Shell Weight  Age  Lost Weight  LostWeight  Sex_F  Sex_I  Sex_M
# 0      8.348928    9     1.247378           1      0      1      0
# 1      3.401940    8     0.170097           1      0      1      0
# 2      6.662133    9     1.219029           1      0      0      1
# 3     14.996885   11     4.316891           1      1      0      0
# 4      5.953395    8     0.850485           1      0      1      0

# %%
df.shape
# Out:
# (74027, 13)

# %%
df.drop('Lost Weight',axis=1,inplace=True)

# %%
df.shape
# Out:
# (74027, 12)

# %%
import matplotlib.pyplot as plt

# %%
x=df['Age']
plt.hist(x)
plt.show()

# %%
df_exceptAge=df
df_exceptAge.head()
# Out:
#    Length  Diameter  Height     Weight  Shucked Weight  Viscera Weight  \
# 0  1.5250    1.1750  0.3750  28.973189       12.728926        6.647958
# 1  1.1000    0.8250  0.2750  10.418441        4.521745        2.324659
# 2  1.3875    1.1125  0.3750  24.777463       11.339800        5.556502
# 3  1.7000    1.4125  0.5000  50.660556       20.354941       10.991839
# 4  1.2500    1.0125  0.3375  23.289114       11.977664        4.507570
#
#    Shell Weight  LostWeight  Sex_F  Sex_I  Sex_M
# 0      8.348928           1      0      1      0
# 1      3.401940           1      0      1      0
# 2      6.662133           1      0      0      1
# 3     14.996885           1      1      0      0
# 4      5.953395           1      0      1      0

# %%
df_age=df[['Age']].copy()
df_age.head()
# Out:
#    Age
# 0    9
# 1    8
# 2    9
# 3   11
# 4    8

# %%
df_exceptAge.head()
# Out:
#    Length  Diameter  Height     Weight  Shucked Weight  Viscera Weight  \
# 0  1.5250    1.1750  0.3750  28.973189       12.728926        6.647958
# 1  1.1000    0.8250  0.2750  10.418441        4.521745        2.324659
# 2  1.3875    1.1125  0.3750  24.777463       11.339800        5.556502
# 3  1.7000    1.4125  0.5000  50.660556       20.354941       10.991839
# 4  1.2500    1.0125  0.3375  23.289114       11.977664        4.507570
#
#    Shell Weight  LostWeight  Sex_F  Sex_I  Sex_M
# 0      8.348928           1      0      1      0
# 1      3.401940           1      0      1      0
# 2      6.662133           1      0      0      1
# 3     14.996885           1      1      0      0
# 4      5.953395           1      0      1      0

# %%
print(df_exceptAge.shape,df_age.shape)
# Out:
# (74027, 11) (74027, 1)

# %%
from sklearn.model_selection import train_test_split


X_train, X_test, y_train, y_test = train_test_split(df_exceptAge_train, df_age_train, test_size=0.3, random_state=42)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-142-a772a9cf993d> in <cell line: 4>()
#       2
#       3
# ----> 4 X_train, X_test, y_train, y_test = train_test_split(df_exceptAge_train, df_age_train, test_size=0.3, random_state=42)
#
# NameError: name 'df_exceptAge_train' is not defined

# %%
print("Size of X_train:", X_train.shape[0])
print("Size of X_test:", X_test.shape[0])
print("Size of y_train:", y_train.shape[0])
print("Size of y_test:", y_test.shape[0])

# Calculate the ratios of train and test sets
train_ratio = X_train.shape[0] / (X_train.shape[0] + X_test.shape[0])
test_ratio = X_test.shape[0] / (X_train.shape[0] + X_test.shape[0])

print("Ratio of train set:", train_ratio)
print("Ratio of test set:", test_ratio)
